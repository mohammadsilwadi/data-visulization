# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# load data base

# %%
sns.get_dataset_names()
dots = sns.load_dataset("dots")
dots.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %% [markdown]
# plot the time and firing_rate

# %%
sns.relplot(
    data=dots, kind="line",
    x="time", y="firing_rate", col="align",
    hue="choice", size="coherence", style="choice",
    facet_kws=dict(sharex=False),
)

# %% [markdown]
# point the (alone) and (class)

# %%
sns.pointplot(data=dots, x="align", y="firing_rate")
# Out:
# <AxesSubplot:xlabel='align', ylabel='firing_rate'>

# %% [markdown]
# show  the (age) and (sex)

# %%
sns.stripplot(data=dots,x='coherence',y='firing_rate')
# Out:
# <AxesSubplot:xlabel='coherence', ylabel='firing_rate'>

# %% [markdown]
# show  the (time) and (coherence)

# %%
sns.relplot(data=dots,x="time",y="coherence")
